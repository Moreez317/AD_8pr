# %% [markdown]
# Практика №8

# %% [markdown]
# Импорт библиотек:

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Задание 1

# %%
street = np.array([80, 98, 75, 91, 78])
garage = np.array([100, 82, 105, 89, 102])

np.corrcoef(street, garage)[0,1]
# Out:
# -0.9999999999999998

# %% [markdown]
# r - практически равен -1. Исходя из этого в итоге мы получили сильную отрицательную коореляцию.

# %% [markdown]
# Задание 2

# %%
plt.grid(True)

plt.title('Диаграмма рассеяния')
plt.xlabel('Число машин на улице')
plt.ylabel('Число машин в гараже')
plt.scatter(street, garage);

# %% [markdown]
# Диаграмма подтвердила вывод из прошлого задания.
